# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv('creditcard.csv')
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_data.sample()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 1288   999  1.237436  0.163731  0.052894  1.198137  0.207893  0.274296
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 1288 -0.001099  0.074395  0.444544  ... -0.168521 -0.257242 -0.152186
#
#            V24       V25     V26       V27       V28  Amount  Class
# 1288 -0.776046  0.756203 -0.2573  0.036162  0.004773     1.0    0.0
#
# [1 rows x 31 columns]

# %%
# dataset informations
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    1986 non-null   int64
#  1   V1      1986 non-null   float64
#  2   V2      1986 non-null   float64
#  3   V3      1986 non-null   float64
#  4   V4      1986 non-null   float64
#  5   V5      1986 non-null   float64
#  6   V6      1986 non-null   float64
#  7   V7      1986 non-null   float64
#  8   V8      1986 non-null   float64
#  9   V9      1986 non-null   float64
#  10  V10     1986 non-null   float64
#  11  V11     1986 non-null   float64
#  12  V12     1986 non-null   float64
#  13  V13     1986 non-null   float64
#  14  V14     1985 non-null   float64
#  15  V15     1985 non-null   float64
#  16  V16     1985 non-null   float64
#  17  V17     1985 non-null   float64
#  18  V18     1985 non-null   float64
#  19  V19     1985 non-null   float64
#  20  V20     1985 non-null   float64
#  21  V21     1985 non-null   float64
#  22  V22     1985 non-null   float64
#  23  V23     1985 non-null   float64
#  24  V24     1985 non-null   float64
#  25  V25     1985 non-null   float64
#  26  V26     1985 non-null   float64
#  27  V27     1985 non-null   float64
#  28  V28     1985 non-null   float64
#  29  Amount  1985 non-null   float64
#  30  Class   1985 non-null   float64
# dtypes: float64(30), int64(1)
# memory usage: 481.1 KB

# %%
# checking the number of missing values in each column
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    1983
# 1.0       2
# Name: count, dtype: int64

# %%
legit = credit_card_data[credit_card_data.Class==0]
fraud = credit_card_data[credit_card_data['Class']==1]

# %%
fraud['Class']
# Out:
# 541    1.0
# 623    1.0
# Name: Class, dtype: float64

# %%
# statistical measures of the data
legit.Amount.describe()
# Out:
# count    1983.000000
# mean       68.404892
# std       241.572682
# min         0.000000
# 25%         4.950000
# 50%        15.090000
# 75%        63.285000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      2.000000
# mean     264.500000
# std      374.059487
# min        0.000000
# 25%      132.250000
# 50%      264.500000
# 75%      396.750000
# max      529.000000
# Name: Amount, dtype: float64

# %%
# compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#              Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    760.974786 -0.281494  0.267200  0.848906  0.146804 -0.077904  0.051713
# 1.0    439.000000 -2.677884 -0.602658 -0.260694  3.143275  0.418809 -1.245684
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0    0.139533 -0.059771  0.014492  ...  0.056618 -0.012217 -0.144666
# 1.0   -1.105907  0.661932 -1.520521  ...  1.114625  0.589464  0.200214
#
#             V23       V24       V25       V26       V27       V28      Amount
# Class
# 0.0   -0.043548  0.013865  0.108318  0.049441  0.027220 -0.001966   68.404892
# 1.0    0.455377  0.013198  0.162159  0.016239  0.004186 -0.053756  264.500000
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=492)

# %%
new_df = pd.concat([legit_sample,fraud],axis=0)

# %%
new_df
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 1050   793 -1.018707  1.386746 -0.126079 -1.677035  3.273957  3.255871
# 1592  1240 -1.369264 -0.412241  1.630455  1.519027 -0.780509  0.777131
# 1624  1260 -2.901810  2.243040  1.240417 -0.493757 -0.416691  2.466447
# 1802  1402 -0.018066  0.640409  1.097033  0.235097  0.347753 -0.411686
# 1641  1267 -0.750103 -4.967487 -0.032746 -0.224437 -3.205115  0.427307
# ...    ...       ...       ...       ...       ...       ...       ...
# 382    280  0.878794 -0.266909  0.409706  1.509808 -0.487798  0.376829
# 1893  1464  1.314894  0.343271 -0.039008  0.497207  0.046249 -0.597255
# 1509  1175 -0.740756  0.375207  0.836767 -0.315216  0.895750  1.666168
# 541    406 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
#
#             V7        V8        V9  ...       V21       V22       V23  \
# 1050  1.497594 -0.315458  0.823087  ... -0.730064 -1.183529 -0.158845
# 1592 -0.354750  0.947234  0.020568  ...  0.159907  0.018881  0.376163
# 1624 -2.139862 -4.738845  0.616180  ...  5.259325 -1.794220  0.395506
# 1802  0.552635 -0.240131  0.046819  ... -0.262232 -0.696158 -0.044294
# 1641 -0.197242 -0.067806 -1.205791  ...  0.360954 -0.924357 -0.900456
# ...        ...       ...       ...  ...       ...       ...       ...
# 382  -0.389288  0.331361  0.702728  ...  0.025056  0.110527 -0.191237
# 1893  0.081123 -0.161125  0.065772  ... -0.340657 -0.970183  0.022930
# 1509  1.040892  0.516526 -1.043534  ... -0.106032 -0.529084  0.423894
# 541  -2.537387  1.391657 -2.770089  ...  0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...  0.661696  0.435477  1.375966
#
#            V24       V25       V26       V27       V28   Amount  Class
# 1050  0.956549 -0.117136 -0.174134 -0.360583 -0.701619     9.31    0.0
# 1592 -0.016902 -0.128956 -0.374310 -0.059878 -0.135826   174.50    0.0
# 1624 -1.202096  0.396541  0.456621  0.154083 -0.145511    17.74    0.0
# 1802 -0.504117 -0.647640  0.108583 -0.232884 -0.169556     1.98    0.0
# 1641  0.366714 -0.190218 -0.377195 -0.139483  0.213044  1127.78    0.0
# ...        ...       ...       ...       ...       ...      ...    ...
# 382  -0.059199  0.504350 -0.271526  0.059100  0.053501   109.15    0.0
# 1893 -0.503987  0.333031  0.146486 -0.023063  0.022569     1.98    0.0
# 1509 -1.403581 -0.469163  0.070848  0.017607  0.035567   142.42    0.0
# 541   0.320198  0.044519  0.177840  0.261145 -0.143276     0.00    1.0
# 623  -0.293803  0.279798 -0.145362 -0.252773  0.035764   529.00    1.0
#
# [494 rows x 31 columns]

# %%
new_df['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0      2
# Name: count, dtype: int64

# %%
new_df.groupby('Class').mean()
# Out:
#              Time        V1        V2        V3        V4        V5        V6  \
# Class
# 0.0    791.345528 -0.363421  0.274488  0.871469  0.046548 -0.007109 -0.014740
# 1.0    439.000000 -2.677884 -0.602658 -0.260694  3.143275  0.418809 -1.245684
#
#              V7        V8        V9  ...       V20       V21       V22  \
# Class                                ...
# 0.0    0.110900 -0.068608  0.061764  ...  0.068933 -0.001300 -0.157319
# 1.0   -1.105907  0.661932 -1.520521  ...  1.114625  0.589464  0.200214
#
#             V23       V24       V25       V26       V27       V28      Amount
# Class
# 0.0   -0.069335  0.031902  0.104222  0.044757  0.019439 -0.021228   61.977276
# 1.0    0.455377  0.013198  0.162159  0.016239  0.004186 -0.053756  264.500000
#
# [2 rows x 30 columns]

# %%
X = new_df.drop(columns='Class', axis=1)
Y = new_df['Class']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
model=LogisticRegression()

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  1.0
